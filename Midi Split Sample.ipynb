# %%
import midi
import pretty_midi
import mido

# %%
samples = midi.midi_to_samples('C:/Users/edgar/Desktop/vgmidi-master/labelled/midi/Final Fantasy_PS1_Final Fantasy VII_Great Warrior.mid')
# Out:
# 0
# 60.0
# 0
# 60.0
# 0
# 60.0
# 0
# 60.0
# 2
# 60.0
# 2
# 60.0
# 2
# 60.0
# 8
# 60.0
# 8
# 60.0
# 8
# 60.0
# 8
# 60.0
# 10
# 60.0
# 10
# 60.0
# 10
# 60.0
# 14
# 60.0
# 16
# 60.0
# 32
# 60.0
# 32
# 60.0
# 32
# 60.0
# 33
# 60.0
# 34
# 60.0
# 37
# 60.0
# 38
# 60.0
# 39
# 60.0
# 40
# 60.0
# 41
# 60.0
# 41
# 60.0
# 41
# 60.0
# 42
# 60.0
# 43
# 60.0
# 43
# 60.0
# 44
# 60.0
# 49
# 60.0
# 49
# 60.0
# 49
# 60.0
# 50
# 60.0
# 51
# 60.0
# 51
# 60.0
# 52
# 60.0
# 55
# 60.0
# 57
# 60.0
# 73
# 60.0
# 73
# 60.0
# 74
# 60.0
# 74
# 60.0
# 75
# 60.0
# 78
# 60.0
# 79
# 60.0
# 80
# 60.0
# 81
# 60.0
# 0
# 62.0
# 2
# 62.0
# 8
# 62.0
# 10
# 62.0
# 15
# 62.0
# 37
# 62.0
# 39
# 62.0
# 41
# 62.0
# 43
# 62.0
# 49
# 62.0
# 51
# 62.0
# 56
# 62.0
# 78
# 62.0
# 80
# 62.0
# 1
# 58.0
# 3
# 58.0
# 5
# 58.0
# 9
# 58.0
# 11
# 58.0
# 13
# 58.0
# 15
# 58.0
# 24
# 58.0
# 33
# 58.0
# 35
# 58.0
# 42
# 58.0
# 44
# 58.0
# 46
# 58.0
# 50
# 58.0
# 52
# 58.0
# 54
# 58.0
# 57
# 58.0
# 65
# 58.0
# 74
# 58.0
# 76
# 58.0
# 2
# ...

# %%
samples[0].shape
# Out:
# (96, 96)

# %%
midi.samples_to_midi(samples)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18868/1218202784.py in <module>
# ----> 1 midi.samples_to_midi(samples)
#
# TypeError: samples_to_midi() missing 2 required positional arguments: 'fname' and 'ticks_per_sample'
